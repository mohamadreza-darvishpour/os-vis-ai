# %% [markdown]
# # **Author: Dr. Mohammad Javad Parseh (Jahrom University)**

# %% [markdown]
# ## Affine Transformation

# %% [markdown]
# ### Introduction
#
# An affine transformation is a geometric transformation that preserves points, lines and planes. It satisfies the following conditions:
#
# *   Collinearity: Points which lie on a line before the transformation
# continue to lie on the line after the transformation.
#
# *   Parallelism: Parallel lines will continue to be parallel after the
# transformation.
#
# *   Convexity: A convex set will continue to be convex after the transformation.
#
# *   Ratios of parallel line segments: The ratio of the length of parallel line segments will continue to be the same after transformation.
#
# In this chapter, we will discuss the common affine transformation such as translation, rotation and scaling.

# %% [markdown]
# ### Translation
#
# Translation is the process of shifting the image along the various axes (`x-axis`, `y-axis` and `z-axis`). For a 2D image, we can perform translation along one or both axes independently.

# %%
import numpy as np
import scipy.misc, math
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
from skimage.transform import AffineTransform, warp

base_path = '/content/drive/MyDrive/Image Processing and Acquisition using Python/Chapter06'
# Opening the image using cv2.
img = cv2.imread(os.path.join(base_path, 'images/angiogram1.png'))
# Converting the image to grayscale.
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# translate by 10 pixels in x and 4 pixels in y
transformation = AffineTransform(translation=(20, 40))
img2 = warp(img1, transformation)
print('translation parameters:')
print(transformation.params)

# Show Images
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
plt.title('original image')
plt.imshow(img1, cmap='gray')

plt.subplot(1,2,2)
plt.title('translated image')
plt.imshow(img2, 'gray')
# Out:
# translation parameters:
# [[ 1. -0. 20.]
#  [ 0.  1. 40.]
#  [ 0.  0.  1.]]

# %% [markdown]
# ### Rotation
#
# Rotation is the process of changing the radial orientation of an image along the various axes with respect to a fixed point.

# %%
import numpy as np
import scipy.misc, math
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
from skimage.transform import AffineTransform, warp

base_path = '/content/drive/MyDrive/Image Processing and Acquisition using Python/Chapter06'
# Opening the image using cv2.
img = cv2.imread(os.path.join(base_path, 'images/angiogram1.png'))
# Converting the image to grayscale.
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# translate by 10 pixels in x and 4 pixels in y
transformation = AffineTransform(rotation=0.2)
img2 = warp(img1, transformation, mode='constant',cval=0.5)
print('translation parameters:')
print(transformation.params)

# Show Images
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
plt.title('original image')
plt.imshow(img1, cmap='gray')

plt.subplot(1,2,2)
plt.title('translated image')
plt.imshow(img2, 'gray')
# Out:
# translation parameters:
# [[ 0.98006658 -0.19866933  0.        ]
#  [ 0.19866933  0.98006658  0.        ]
#  [ 0.          0.          1.        ]]

# %% [markdown]
# ### Scaling
#
# Scaling is a process of changing the distance (compression or elongation) between points in one or more axes. This change in distance causes the object in the image to appear larger or smaller than the original input. The scaling factor may be different across different axes.

# %%
import numpy as np
import scipy.misc, math
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
from skimage.transform import AffineTransform, warp

base_path = '/content/drive/MyDrive/Image Processing and Acquisition using Python/Chapter06'
# Opening the image using cv2.
img = cv2.imread(os.path.join(base_path, 'images/angiogram1.png'))
# Converting the image to grayscale.
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# translate by 10 pixels in x and 4 pixels in y
transformation = AffineTransform(scale=(0.5,0.5))
img2 = warp(img1, transformation, mode='constant',cval=0.1)
print('translation parameters:')
print(transformation.params)

# Show Images
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
plt.title('original image')
plt.imshow(img1, cmap='gray')

plt.subplot(1,2,2)
plt.title('translated image')
plt.imshow(img2, 'gray')
# Out:
# translation parameters:
# [[ 0.5 -0.   0. ]
#  [ 0.   0.5  0. ]
#  [ 0.   0.   1. ]]
